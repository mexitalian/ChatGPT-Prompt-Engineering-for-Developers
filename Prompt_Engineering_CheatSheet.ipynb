# %% [markdown]
# # 🧠 ChatGPT Prompt Engineering Cheat Sheet
# Inspired by DeepLearning.AI's course

# %% [markdown]
# ## 🎯 Prompting Guidelines
#
# - **Be clear and specific**
# - **Provide context**
# - **Use delimiters**
# - **Break tasks into steps**
# - **Specify output format**
# - **Use few-shot examples**
# - **Iterate and refine**

# %% [markdown]
# ## 🧪 Prompt Templates
#
# ### Summarization
