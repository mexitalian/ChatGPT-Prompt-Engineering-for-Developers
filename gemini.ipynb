# %%
import os
from dotenv import load_dotenv, find_dotenv
import google.generativeai as genai

_ = load_dotenv(find_dotenv()) # read local .env file
api_key  = os.getenv('GEMINI_API_KEY')

# Configure with your API key
genai.configure(api_key=api_key)

# Pick a Gemini model (text-only for now)
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
# Make a simple request
response = model.generate_content("Hello Gemini, can you introduce yourself?")
print(response.text)
# Out:
# Hi there! I'd be happy to introduce myself.
#
# I am **Gemini**, a large language model trained by Google.
#
# My purpose is to assist you by understanding and responding to a wide range of prompts and questions. I can:
#
# *   **Provide information** on various topics.
# *   **Generate different kinds of creative text formats**, like poems, code, scripts, musical pieces, email, letters, etc.
# *   **Summarize** complex texts or concepts.
# *   **Help with brainstorming** and problem-solving.
# *   **Translate languages**.
# *   **Engage in natural language conversations** to assist with tasks or provide insights.
#
# Essentially, I'm here to be a helpful and informative resource. Think of me as a digital assistant or a creative partner, constantly learning and evolving to serve you better.
#
# How can I help you today?
